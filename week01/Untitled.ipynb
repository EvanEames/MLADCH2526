# %%
import pandas as pd
import openpyxl

# %%
df = pd.read_csv('pandascsv.csv')

# %%
df = pd.read_excel('pandascsv.xlsx')

# %%
dictionary = I AM DEFINING A DICTIONARY HERE BUT YOU DON'T KNOW HOW TO BUT DON'T WORRY YOU WILL THIS AFTERNOON
df = pd.DataFrame(dictionary)

# %%
df
# Out:
#       Name  Age           City  Salary
# 0     John   25       New York   50000
# 1    Alice   32  San Francisco   75000
# 2  Michael   28        Chicago   60000
# 3     Emma   35    Los Angeles   80000

# %%
df.head(3)
# Out:
#       Name  Age           City  Salary
# 0     John   25       New York   50000
# 1    Alice   32  San Francisco   75000
# 2  Michael   28        Chicago   60000

# %%
df.tail(2)
# Out:
#       Name  Age         City  Salary
# 2  Michael   28      Chicago   60000
# 3     Emma   35  Los Angeles   80000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   City    4 non-null      object
#  3   Salary  4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 260.0+ bytes

# %%
df.shape
# Out:
# (4, 4)

# %%
df.describe()
# Out:
#              Age        Salary
# count   4.000000      4.000000
# mean   30.000000  66250.000000
# std     4.396969  13768.926368
# min    25.000000  50000.000000
# 25%    27.250000  57500.000000
# 50%    30.000000  67500.000000
# 75%    32.750000  76250.000000
# max    35.000000  80000.000000

# %%
column = df['Salary']

# %%
column.tolist()
# Out:
# [50000, 75000, 60000, 80000]

# %%
list_of_columns = ['Name','Age']
df[list_of_columns]
# Out:
#       Name  Age
# 0     John   25
# 1    Alice   32
# 2  Michael   28
# 3     Emma   35

# %%
df2 = df[['Name','Age']]

# %%
df2
# Out:
#       Name  Age
# 0     John   25
# 1    Alice   32
# 2  Michael   28
# 3     Emma   35

# %%
df
# Out:
#       Name  Age           City  Salary
# 0     John   25       New York   50000
# 1    Alice   32  San Francisco   75000
# 2  Michael   28        Chicago   60000
# 3     Emma   35    Los Angeles   80000

# %%
city_of_interest = df.loc[3,'City']

# %%
city_of_interest
# Out:
# 'Los Angeles'

# %%
list_df = [["John", 25, "New York", 50000]]

# %%
list_df[0]
# Out:
# ['John', 25, 'New York', 50000]

# %%
df.iloc[0]
# Out:
# Name          John
# Age             25
# City      New York
# Salary       50000
# Name: 0, dtype: object

# %%
df
# Out:
#       Name  Age           City  Salary
# 0     John   25       New York   50000
# 1    Alice   32  San Francisco   75000
# 2  Michael   28        Chicago   60000
# 3     Emma   35    Los Angeles   80000

# %%
df['Relationship Status'] = 'Single'

# %%
df
# Out:
#       Name  Age           City  Salary Relationship Status
# 0     John   25       New York   50000              Single
# 1    Alice   32  San Francisco   75000              Single
# 2  Michael   28        Chicago   60000              Single
# 3     Emma   35    Los Angeles   80000              Single

# %%
df['Relationship Status'] = ['Single', 'Married', 'Widowed', 'No comment']

# %%
df
# Out:
#       Name  Age           City  Salary Relationship Status
# 0     John   25       New York   50000              Single
# 1    Alice   32  San Francisco   75000             Married
# 2  Michael   28        Chicago   60000             Widowed
# 3     Emma   35    Los Angeles   80000          No comment

# %%
df.loc[df['Name'] != 'John', 'Relationship Status'] = 'Its Complicated'

# %%
df
# Out:
#       Name  Age           City  Salary Relationship Status
# 0     John   25       New York   50000     Its Complicated
# 1    Alice   32  San Francisco   75000             Married
# 2  Michael   28        Chicago   60000             Widowed
# 3     Emma   35    Los Angeles   80000          No comment

# %%
df.loc[df['Salary'] >= 65000, 'City'] = 'Stuttgart'

# %%
df
# Out:
#       Name  Age      City  Salary Relationship Status
# 0     John   25  New York   50000     Its Complicated
# 1    Alice   32    Munich   75000             Married
# 2  Michael   28    Munich   60000             Widowed
# 3     Emma   35    Munich   80000          No comment

# %%
df = df.drop(columns=['Relationship Status'])

# %%
df
# Out:
#       Name  Age      City  Salary
# 0     John   25  New York   50000
# 1    Alice   32    Munich   75000
# 2  Michael   28    Munich   60000
# 3     Emma   35    Munich   80000

# %%
df = df.sort_values(by='Salary')

# %%
df
# Out:
#       Name  Age      City  Salary
# 0     John   25  New York   50000
# 2  Michael   28    Munich   60000
# 1    Alice   32    Munich   75000
# 3     Emma   35    Munich   80000

# %%
df
# Out:
#       Name  Age           City  Salary
# 0     John   25       New York   50000
# 1    Alice   32  San Francisco   75000
# 2  Michael   28        Chicago   60000
# 3     Emma   35    Los Angeles   80000

# %%
grouped = df.groupby('City')

# %%
grouped.mean(numeric_only = True)
# Out:
#                 Age   Salary
# City
# Chicago        28.0  60000.0
# Los Angeles    35.0  80000.0
# New York       25.0  50000.0
# San Francisco  32.0  75000.0

# %%
grouped.sum(numeric_only = True)
# Out:
#                Age  Salary
# City
# Chicago         28   60000
# Los Angeles     35   80000
# New York        25   50000
# San Francisco   32   75000

# %%
grouped.count()
# Out:
#                Name  Age  Salary
# City
# Chicago           1    1       1
# Los Angeles       1    1       1
# New York          1    1       1
# San Francisco     1    1       1

# %%
df
# Out:
#       Name  Age           City  Salary
# 0     John   25       New York   50000
# 1    Alice   32  San Francisco   75000
# 2  Michael   28        Chicago   60000
# 3     Emma   35    Los Angeles   80000

# %%
df = df.replace('New York', 'Los Angeles')

# %%
df
# Out:
#       Name  Age           City  Salary
# 0     John   25    Los Angeles   50000
# 1    Alice   32  San Francisco   75000
# 2  Michael   28        Chicago   60000
# 3     Emma   35    Los Angeles   80000

# %%
grouped = df.groupby('City')

# %%
grouped.count()
# Out:
#                Name  Age  Salary
# City
# Chicago           1    1       1
# Los Angeles       2    2       2
# San Francisco     1    1       1

# %%
df
# Out:
#       Name  Age           City  Salary
# 0     John   25    Los Angeles   50000
# 1    Alice   32  San Francisco   75000
# 2  Michael   28        Chicago   60000
# 3     Emma   35    Los Angeles   80000

# %%
#list = ["eggs", "beans", "milk", "chocolate"]
for index, row in df.iterrows():
    print(row['Name'] + ' lives in ' + row['City'] + ' and he is ' + str(row['Age']) + ' years old.')
# Out:
# John lives in Los Angeles and he is 25 years old.
# Alice lives in San Francisco and he is 32 years old.
# Michael lives in Chicago and he is 28 years old.
# Emma lives in Los Angeles and he is 35 years old.

# %%
for i in range(len_df):
    df.iloc[i]......
    df2.iloc[i]

# %%
df = pd.read_csv('unesco_heritage_sites.csv')

# %%
df.columns.tolist()
# Out:
# ['SiteID',
#  'Name',
#  'Country',
#  'Category',
#  'YearInscribed',
#  'VisitorsPerYear',
#  'Area_km2',
#  'Threatened']

# %%
def get_column_name(df):
    list_of_columns = df.columns.tolist()
    return list_of_columns

# %%
get_column_name(df)
# Out:
# ['SiteID',
#  'Name',
#  'Country',
#  'Category',
#  'YearInscribed',
#  'VisitorsPerYear',
#  'Area_km2',
#  'Threatened']

# %%
df[df['Category'] == 'Cultural']
# Out:
#     SiteID                 Name   Country  Category  YearInscribed  \
# 0        1  Great Wall of China     China  Cultural           1987
# 1        2         Machu Picchu      Peru  Cultural           1983
# 2        3     Pyramids of Giza     Egypt  Cultural           1979
# 4        5            Colosseum     Italy  Cultural           1980
# 6        7           Stonehenge        UK  Cultural           1986
# 7        8            Taj Mahal     India  Cultural           1983
# 9       10           Angkor Wat  Cambodia  Cultural           1992
# 11      12  Acropolis of Athens    Greece  Cultural           1987
# 13      14                Petra    Jordan  Cultural           1985
# 14      15         Eiffel Tower    France  Cultural           1991
#
#     VisitorsPerYear  Area_km2 Threatened
# 0              10.0  21196.00         No
# 1               1.5     32.00         No
# 2              14.0     16.00         No
# 4               7.6      0.02         No
# ...

# %%
def filter_by_category(df, category):
    new_df = df[df['Category'] == category]
    return new_df

# %%
filter_by_category(df, 'Cultural')
# Out:
#     SiteID                 Name   Country  Category  YearInscribed  \
# 0        1  Great Wall of China     China  Cultural           1987
# 1        2         Machu Picchu      Peru  Cultural           1983
# 2        3     Pyramids of Giza     Egypt  Cultural           1979
# 4        5            Colosseum     Italy  Cultural           1980
# 6        7           Stonehenge        UK  Cultural           1986
# 7        8            Taj Mahal     India  Cultural           1983
# 9       10           Angkor Wat  Cambodia  Cultural           1992
# 11      12  Acropolis of Athens    Greece  Cultural           1987
# 13      14                Petra    Jordan  Cultural           1985
# 14      15         Eiffel Tower    France  Cultural           1991
#
#     VisitorsPerYear  Area_km2 Threatened
# 0              10.0  21196.00         No
# 1               1.5     32.00         No
# 2              14.0     16.00         No
# 4               7.6      0.02         No
# ...

# %%
def count_sites_per_country(df, country):
    SOME STUFF
    return new_df
